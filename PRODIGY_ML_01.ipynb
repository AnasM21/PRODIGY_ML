# %%
#installing the libraries 
# Install matplotlib
# !pip install matplotlib

# Install seaborn
# !pip install seaborn

# Install numpy
# !pip install numpy

# Install pandas
# !pip install pandas
# Install Sickit-learn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: matplotlib in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\yoru\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yoru\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\yoru\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from seaborn) (1.26.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\yoru\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yoru\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\yoru\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: numpy in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (1.26.3)
# Requirement already satisfied: pandas in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yoru\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\yoru\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yoru\anaconda3\envs\notebook\lib\site-packages (from scikit-learn) (3.2.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['median_house_value'], axis=1)
Y = data['median_house_value']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
train_data = X_train.join(Y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3703     -118.37     34.18                33.0       1829.0           512.0
# 5297     -118.44     34.07                21.0        730.0           263.0
# 3415     -118.41     34.29                35.0       1008.0           204.0
# 15950    -122.44     37.72                49.0       1557.0           405.0
# 10618    -117.82     33.68                 4.0       1346.0           213.0
# ...          ...       ...                 ...          ...             ...
# 19266    -122.72     38.44                52.0        188.0            62.0
# 11547    -118.02     33.74                26.0       3842.0           609.0
# 13174    -121.06     36.72                23.0        395.0            70.0
# 8866     -118.39     34.06                39.0       3299.0           831.0
# 2704     -115.57     32.83                31.0       1494.0           289.0
#
#        population  households  median_income ocean_proximity  \
# 3703       1345.0       500.0         3.1629       <1H OCEAN
# 5297        965.0       224.0         2.0511       <1H OCEAN
# 3415       1162.0       215.0         3.3500       <1H OCEAN
# 15950      1173.0       385.0         3.4605        NEAR BAY
# 10618       603.0       219.0         8.7974       <1H OCEAN
# ...           ...         ...            ...             ...
# 19266       301.0        72.0         0.9437       <1H OCEAN
# 11547      1961.0       595.0         6.1280       <1H OCEAN
# 13174       166.0        52.0         2.2132          INLAND
# 8866       1649.0       759.0         3.3295       <1H OCEAN
# 2704        959.0       284.0         3.5282          INLAND
#
#        median_house_value
# 3703             198900.0
# 5297             350000.0
# 3415             147600.0
# 15950            265000.0
# 10618            360600.0
# ...                   ...
# 19266            129200.0
# 11547            248200.0
# 13174            100000.0
# 8866             500001.0
# 2704              67500.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#Data Pre-processing

# %%
train_data.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924565           -0.115097     0.046047
# latitude            -0.924565  1.000000            0.016286    -0.035036
# housing_median_age  -0.115097  0.016286            1.000000    -0.357130
# total_rooms          0.046047 -0.035036           -0.357130     1.000000
# total_bedrooms       0.069964 -0.065033           -0.317394     0.931397
# population           0.098912 -0.105393           -0.294046     0.854923
# households           0.056385 -0.069424           -0.300342     0.918282
# median_income       -0.014127 -0.080723           -0.121654     0.196671
# median_house_value  -0.048571 -0.141580            0.103842     0.132660
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069964    0.098912    0.056385      -0.014127
# latitude                 -0.065033   -0.105393   -0.069424      -0.080723
# housing_median_age       -0.317394   -0.294046   -0.300342      -0.121654
# total_rooms               0.931397    0.854923    0.918282       0.196671
# total_bedrooms            1.000000    0.875811    0.978448      -0.007725
# population                0.875811    1.000000    0.906432       0.005169
# households                0.978448    0.906432    1.000000       0.013539
# median_income            -0.007725    0.005169    0.013539       1.000000
# median_house_value        0.049623   -0.025685    0.065311       0.688274
#
#                     median_house_value
# longitude                    -0.048571
# latitude                     -0.141580
# housing_median_age            0.103842
# total_rooms                   0.132660
# total_bedrooms                0.049623
# population                   -0.025685
# households                    0.065311
# median_income                 0.688274
# median_house_value            1.000000

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3703     -118.37     34.18                33.0     7.512071        6.240276
# 5297     -118.44     34.07                21.0     6.594413        5.575949
# 3415     -118.41     34.29                35.0     6.916715        5.323010
# 15950    -122.44     37.72                49.0     7.351158        6.006353
# 10618    -117.82     33.68                 4.0     7.205635        5.365976
# ...          ...       ...                 ...          ...             ...
# 19266    -122.72     38.44                52.0     5.241747        4.143135
# 11547    -118.02     33.74                26.0     8.254009        6.413459
# 13174    -121.06     36.72                23.0     5.981414        4.262680
# 8866     -118.39     34.06                39.0     8.101678        6.723832
# 2704     -115.57     32.83                31.0     7.309881        5.669881
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 3703     7.204893    6.216606         3.1629            198900.0       True
# 5297     6.873164    5.416100         2.0511            350000.0       True
# 3415     7.058758    5.375278         3.3500            147600.0       True
# 15950    7.068172    5.955837         3.4605            265000.0      False
# 10618    6.403574    5.393628         8.7974            360600.0       True
# ...           ...         ...            ...                 ...        ...
# 19266    5.710427    4.290459         0.9437            129200.0       True
# 11547    7.581720    6.390241         6.1280            248200.0       True
# 13174    5.117994    3.970292         2.2132            100000.0      False
# 8866     7.408531    6.633318         3.3295            500001.0       True
# 2704     6.866933    5.652489         3.5282             67500.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 3703    False   False     False       False
# 5297    False   False     False       False
# 3415    False   False     False       False
# 15950   False   False      True       False
# 10618   False   False     False       False
# ...       ...     ...       ...         ...
# 19266   False   False     False       False
# 11547   False   False     False       False
# 13174    True   False     False       False
# 8866    False   False     False       False
# 2704     True   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude', data=train_data, hue='median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# Training the Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train, Y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()

reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(Y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3222     -119.66     36.32                24.0     7.883446        6.343880
# 17219    -119.70     34.47                32.0     8.223091        6.345636
# 6826     -118.10     34.09                46.0     7.945555        6.265301
# 10797    -117.92     33.61                18.0     7.338888        6.054439
# 15129    -116.91     32.86                10.0     8.216088        6.732211
# ...          ...       ...                 ...          ...             ...
# 16036    -122.46     37.72                48.0     7.433075        5.828946
# 18829    -123.26     41.86                25.0     7.760041        6.278521
# 1768     -122.34     37.95                39.0     7.594381        6.059123
# 17992    -121.95     37.29                30.0     8.225503        6.701960
# 4001     -118.65     34.18                26.0     8.435549        6.487684
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 3222     7.334982    6.100319         2.3256             56800.0      False
# 17219    7.173958    6.269096         7.7261            500001.0       True
# 6826     7.268920    6.255750         3.8906            238300.0       True
# 10797    6.054439    5.666427         5.3369            312500.0       True
# 15129    7.745436    6.633318         2.5365            139500.0       True
# ...           ...         ...            ...                 ...        ...
# 16036    6.870053    5.762051         3.2875            221500.0      False
# 18829    7.019297    6.052089         2.7222             64600.0      False
# 1768     6.948897    5.955837         3.2333            135100.0      False
# 17992    7.514800    6.715383         3.4505            260000.0       True
# 4001     7.478735    6.467699         7.4918            367600.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 3222     True   False     False       False       0.804709         1.292301
# 17219   False   False     False       False       0.771685         1.311687
# 6826    False   False     False       False       0.788529         1.270120
# 10797   False   False     False       False       0.824980         1.295153
# 15129   False   False     False       False       0.819394         1.238609
# ...       ...     ...       ...         ...            ...              ...
# 16036   False   False     False        True       0.784190         1.290005
# 18829    True   False     False       False       0.809084         1.282209
# 1768    False   False      True       False       0.797843         1.275116
# 17992   False   False     False       False       0.814778         1.224875
# 4001    False   False     False       False       0.769089         1.304258
#
# [4087 rows x 16 columns]

# %%
X_test, Y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test, Y_test)
# Out:
# 0.6679118522205564

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train_s, Y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s, Y_test)
# Out:
# 0.8061896101514758

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
import numpy as np

forest = RandomForestRegressor()

param_dist = {
    "n_estimators": [100, 200, 300],
    "min_samples_split": [2, 4],
    "max_depth": [None, 4, 8]
}

random_search = RandomizedSearchCV(
    forest, param_dist, n_iter=10, cv=5, scoring='neg_mean_squared_error', 
    return_train_score=True, random_state=42, n_jobs=-1)

random_search.fit(X_train_s, Y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [None, 4, 8],
#                                         'min_samples_split': [2, 4],
#                                         'n_estimators': [100, 200, 300]},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_mean_squared_error')

# %%
random_search.best_estimator_
# Out:
# RandomForestRegressor(n_estimators=300)
