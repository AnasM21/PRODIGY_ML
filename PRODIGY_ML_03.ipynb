# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %% [markdown]
# # Load Dataset

# %%
X_train = np.loadtxt('input.csv', delimiter = ',')
Y_train = np.loadtxt('labels.csv', delimiter = ',')

X_test = np.loadtxt('input_test.csv', delimiter = ',')
Y_test = np.loadtxt('labels_test.csv', delimiter = ',')

# %%
X_train = X_train.reshape(len(X_train), 100, 100, 3)
Y_train = Y_train.reshape(len(Y_train), 1)

X_test = X_test.reshape(len(X_test), 100, 100, 3)
Y_test = Y_test.reshape(len(Y_test), 1)

X_train = X_train/255.0
X_test = X_test/255.0

# %%
print("Shape of X_train: ", X_train.shape)
print("Shape of Y_train: ", Y_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of Y_test: ", Y_test.shape)
# Out:
# Shape of X_train:  (2000, 100, 100, 3)
# Shape of Y_train:  (2000, 1)
# Shape of X_test:  (400, 100, 100, 3)
# Shape of Y_test:  (400, 1)

# %%
idx = random.randint(0, len(X_train))
plt.imshow(X_train[idx, :])
plt.show()

# %% [markdown]
# # Model

# %%
model = Sequential([
    Conv2D(32, (3,3), activation = 'relu', input_shape = (100, 100, 3)),
    MaxPooling2D((2,2)),
    
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dense(64, activation = 'relu'),
    Dense(1, activation = 'sigmoid')
])

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (100, 100, 3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(32, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(X_train, Y_train, epochs = 100, batch_size = 64)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 11s 16ms/step - loss: 0.7610 - accuracy: 0.5200
# Epoch 2/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.6559 - accuracy: 0.6200
# Epoch 3/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.5713 - accuracy: 0.7040
# Epoch 4/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.5132 - accuracy: 0.7355
# Epoch 5/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.4445 - accuracy: 0.7895
# Epoch 6/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.3849 - accuracy: 0.8260
# Epoch 7/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.3230 - accuracy: 0.8625
# Epoch 8/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.2496 - accuracy: 0.9075
# Epoch 9/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1971 - accuracy: 0.9350
# Epoch 10/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1428 - accuracy: 0.9510
# Epoch 11/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1024 - accuracy: 0.9680
# Epoch 12/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0975 - accuracy: 0.9690
# Epoch 13/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0635 - accuracy: 0.9830
# Epoch 14/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0391 - accuracy: 0.9940
# Epoch 15/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0245 - accuracy: 0.9965
# Epoch 16/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0162 - accuracy: 0.9985
# Epoch 17/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 18/100
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 19/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 20/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 21/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 22/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 23/100
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 24/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 25/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 26/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 27/100
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 28/100
# 32/32 [==============================] - 0s 14ms/step - loss: 9.4621e-04 - accuracy: 1.0000
# Epoch 29/100
# 32/32 [==============================] - 0s 14ms/step - loss: 8.4103e-04 - accuracy: 1.0000
# Epoch 30/100
# 32/32 [==============================] - 0s 14ms/step - loss: 7.5016e-04 - accuracy: 1.0000
# Epoch 31/100
# 32/32 [==============================] - 0s 15ms/step - loss: 6.8333e-04 - accuracy: 1.0000
# Epoch 32/100
# 32/32 [==============================] - 0s 14ms/step - loss: 6.2392e-04 - accuracy: 1.0000
# Epoch 33/100
# 32/32 [==============================] - 0s 14ms/step - loss: 5.6857e-04 - accuracy: 1.0000
# Epoch 34/100
# 32/32 [==============================] - 0s 14ms/step - loss: 5.2021e-04 - accuracy: 1.0000
# Epoch 35/100
# 32/32 [==============================] - 0s 14ms/step - loss: 4.8921e-04 - accuracy: 1.0000
# Epoch 36/100
# 32/32 [==============================] - 0s 13ms/step - loss: 4.5364e-04 - accuracy: 1.0000
# Epoch 37/100
# 32/32 [==============================] - 0s 14ms/step - loss: 4.2055e-04 - accuracy: 1.0000
# Epoch 38/100
# 32/32 [==============================] - 0s 14ms/step - loss: 3.8864e-04 - accuracy: 1.0000
# Epoch 39/100
# 32/32 [==============================] - 1s 19ms/step - loss: 3.6389e-04 - accuracy: 1.0000
# Epoch 40/100
# 32/32 [==============================] - 0s 15ms/step - loss: 3.3796e-04 - accuracy: 1.0000
# Epoch 41/100
# 32/32 [==============================] - 0s 15ms/step - loss: 3.1788e-04 - accuracy: 1.0000
# Epoch 42/100
# 32/32 [==============================] - 0s 15ms/step - loss: 2.9628e-04 - accuracy: 1.0000
# Epoch 43/100
# 32/32 [==============================] - 0s 14ms/step - loss: 2.7855e-04 - accuracy: 1.0000
# Epoch 44/100
# 32/32 [==============================] - 0s 14ms/step - loss: 2.6101e-04 - accuracy: 1.0000
# Epoch 45/100
# 32/32 [==============================] - 0s 14ms/step - loss: 2.4854e-04 - accuracy: 1.0000
# Epoch 46/100
# 32/32 [==============================] - 0s 14ms/step - loss: 2.3271e-04 - accuracy: 1.0000
# Epoch 47/100
# 32/32 [==============================] - 0s 14ms/step - loss: 2.2325e-04 - accuracy: 1.0000
# Epoch 48/100
# 32/32 [==============================] - 0s 14ms/step - loss: 2.1034e-04 - accuracy: 1.0000
# Epoch 49/100
# 32/32 [==============================] - 0s 15ms/step - loss: 1.9918e-04 - accuracy: 1.0000
# Epoch 50/100
# 32/32 [==============================] - 0s 14ms/step - loss: 1.8758e-04 - accuracy: 1.0000
# Epoch 51/100
# 32/32 [==============================] - 0s 14ms/step - loss: 1.7975e-04 - accuracy: 1.0000
# Epoch 52/100
# 32/32 [==============================] - 0s 13ms/step - loss: 1.6936e-04 - accuracy: 1.0000
# Epoch 53/100
# 32/32 [==============================] - 0s 14ms/step - loss: 1.6413e-04 - accuracy: 1.0000
# Epoch 54/100
# 32/32 [==============================] - 0s 15ms/step - loss: 1.5566e-04 - accuracy: 1.0000
# Epoch 55/100
# 32/32 [==============================] - 0s 14ms/step - loss: 1.4715e-04 - accuracy: 1.0000
# Epoch 56/100
# 32/32 [==============================] - 0s 14ms/step - loss: 1.4062e-04 - accuracy: 1.0000
# Epoch 57/100
# 32/32 [==============================] - 0s 14ms/step - loss: 1.3487e-04 - accuracy: 1.0000
# Epoch 58/100
# 32/32 [==============================] - 0s 14ms/step - loss: 1.2923e-04 - accuracy: 1.0000
# Epoch 59/100
# 32/32 [==============================] - 0s 14ms/step - loss: 1.2281e-04 - accuracy: 1.0000
# Epoch 60/100
# 32/32 [==============================] - 0s 14ms/step - loss: 1.1809e-04 - accuracy: 1.0000
# Epoch 61/100
# 32/32 [==============================] - 0s 15ms/step - loss: 1.1285e-04 - accuracy: 1.0000
# Epoch 62/100
# 32/32 [==============================] - 0s 13ms/step - loss: 1.0850e-04 - accuracy: 1.0000
# Epoch 63/100
# 32/32 [==============================] - 0s 13ms/step - loss: 1.0373e-04 - accuracy: 1.0000
# Epoch 64/100
# 32/32 [==============================] - 0s 14ms/step - loss: 9.9484e-05 - accuracy: 1.0000
# Epoch 65/100
# 32/32 [==============================] - 0s 14ms/step - loss: 9.5848e-05 - accuracy: 1.0000
# Epoch 66/100
# 32/32 [==============================] - 0s 13ms/step - loss: 9.2702e-05 - accuracy: 1.0000
# Epoch 67/100
# 32/32 [==============================] - 0s 13ms/step - loss: 8.8038e-05 - accuracy: 1.0000
# Epoch 68/100
# 32/32 [==============================] - 0s 13ms/step - loss: 8.5658e-05 - accuracy: 1.0000
# Epoch 69/100
# 32/32 [==============================] - 0s 13ms/step - loss: 8.2571e-05 - accuracy: 1.0000
# Epoch 70/100
# 32/32 [==============================] - 0s 13ms/step - loss: 7.9024e-05 - accuracy: 1.0000
# Epoch 71/100
# 32/32 [==============================] - 0s 13ms/step - loss: 7.6945e-05 - accuracy: 1.0000
# Epoch 72/100
# 32/32 [==============================] - 0s 13ms/step - loss: 7.3145e-05 - accuracy: 1.0000
# Epoch 73/100
# 32/32 [==============================] - 0s 14ms/step - loss: 7.1052e-05 - accuracy: 1.0000
# Epoch 74/100
# 32/32 [==============================] - 0s 14ms/step - loss: 6.9179e-05 - accuracy: 1.0000
# Epoch 75/100
# 32/32 [==============================] - 0s 15ms/step - loss: 6.5873e-05 - accuracy: 1.0000
# Epoch 76/100
# 32/32 [==============================] - 0s 14ms/step - loss: 6.4149e-05 - accuracy: 1.0000
# Epoch 77/100
# 32/32 [==============================] - 0s 15ms/step - loss: 6.1419e-05 - accuracy: 1.0000
# Epoch 78/100
# 32/32 [==============================] - 0s 15ms/step - loss: 5.9494e-05 - accuracy: 1.0000
# Epoch 79/100
# 32/32 [==============================] - 0s 14ms/step - loss: 5.7766e-05 - accuracy: 1.0000
# Epoch 80/100
# 32/32 [==============================] - 0s 13ms/step - loss: 5.5687e-05 - accuracy: 1.0000
# Epoch 81/100
# 32/32 [==============================] - 0s 14ms/step - loss: 5.3815e-05 - accuracy: 1.0000
# Epoch 82/100
# 32/32 [==============================] - 0s 14ms/step - loss: 5.1900e-05 - accuracy: 1.0000
# Epoch 83/100
# 32/32 [==============================] - 0s 14ms/step - loss: 5.0355e-05 - accuracy: 1.0000
# Epoch 84/100
# 32/32 [==============================] - 0s 13ms/step - loss: 4.8932e-05 - accuracy: 1.0000
# Epoch 85/100
# 32/32 [==============================] - 0s 13ms/step - loss: 4.7109e-05 - accuracy: 1.0000
# Epoch 86/100
# 32/32 [==============================] - 0s 13ms/step - loss: 4.5878e-05 - accuracy: 1.0000
# Epoch 87/100
# 32/32 [==============================] - 0s 13ms/step - loss: 4.4400e-05 - accuracy: 1.0000
# Epoch 88/100
# 32/32 [==============================] - 0s 13ms/step - loss: 4.3246e-05 - accuracy: 1.0000
# Epoch 89/100
# 32/32 [==============================] - 0s 13ms/step - loss: 4.1557e-05 - accuracy: 1.0000
# Epoch 90/100
# 32/32 [==============================] - 0s 13ms/step - loss: 4.1082e-05 - accuracy: 1.0000
# Epoch 91/100
# 32/32 [==============================] - 0s 13ms/step - loss: 3.9241e-05 - accuracy: 1.0000
# Epoch 92/100
# 32/32 [==============================] - 0s 13ms/step - loss: 3.8290e-05 - accuracy: 1.0000
# Epoch 93/100
# 32/32 [==============================] - 0s 13ms/step - loss: 3.7106e-05 - accuracy: 1.0000
# Epoch 94/100
# 32/32 [==============================] - 0s 13ms/step - loss: 3.5889e-05 - accuracy: 1.0000
# Epoch 95/100
# 32/32 [==============================] - 0s 13ms/step - loss: 3.4748e-05 - accuracy: 1.0000
# Epoch 96/100
# 32/32 [==============================] - 0s 13ms/step - loss: 3.3975e-05 - accuracy: 1.0000
# Epoch 97/100
# 32/32 [==============================] - 0s 13ms/step - loss: 3.3120e-05 - accuracy: 1.0000
# Epoch 98/100
# 32/32 [==============================] - 0s 13ms/step - loss: 3.1984e-05 - accuracy: 1.0000
# Epoch 99/100
# 32/32 [==============================] - 0s 14ms/step - loss: 3.1191e-05 - accuracy: 1.0000
# Epoch 100/100
# 32/32 [==============================] - 0s 13ms/step - loss: 3.0184e-05 - accuracy: 1.0000

# %%
model.evaluate(X_test, Y_test)
# Out:
# 13/13 [==============================] - 0s 4ms/step - loss: 2.9659 - accuracy: 0.6550
# [2.965928077697754, 0.6549999713897705]

# %% [markdown]
# # Making predictions

# %%
idx2 = random.randint(0, len(Y_test))
plt.imshow(X_test[idx2, :])
plt.show()

y_pred = model.predict(X_test[idx2, :].reshape(1, 100, 100, 3))
y_pred = y_pred > 0.5

if(y_pred == 0):
    pred = 'dog'
else:
    pred = 'cat'
    
print("Our model says it is a :", pred)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[False]]
# Our model says it is a : dog
